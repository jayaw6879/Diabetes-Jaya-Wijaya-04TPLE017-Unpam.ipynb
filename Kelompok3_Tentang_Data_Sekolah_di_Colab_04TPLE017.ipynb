# %% [markdown]
# <a href="https://colab.research.google.com/github/jayaw6879/Diabetes-Jaya-Wijaya-04TPLE017-Unpam.ipynb/blob/main/Kelompok3_Tentang_Data_Sekolah_di_Colab_04TPLE017.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle

# %%
# !pip install -q kaggle

# %%
# !chmod 600 ~/.kaggle/kaggle.json #fungsi untuk memberikan izin akses file

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
filename = "../input/StudentsPerformance.csv"
df = pd.read_csv("StudentsPerformance.csv")
df.head(1)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
ability = ['math', 'reading', 'writing']
score = [72, 72, 74]
ax.pie(score, labels = ability,autopct='%1.2f%%')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ability = ['math', 'reading', 'writing']
score = [72, 72, 74]
ax.bar(ability, score)
plt.show()

# %%
filename = "../input/StudentsPerformance.csv"
df = pd.read_csv("StudentsPerformance.csv")
df.head(3)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93

# %%
import numpy as np
import matplotlib.pyplot as plt
data =[[72, 72, 74],
       [69, 90, 88],
       [90, 95, 93]]
x = np.arange(3)
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.bar(x + 0.00, data[0], color = 'b', width = 0.25)
ax.bar(x + 0.25, data[1], color = 'g', width = 0.25)
ax.bar(x + 0.50, data[2], color = 'r', width = 0.25)
# Out:
# <BarContainer object of 3 artists>

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
plt.figure(figsize=(10,6))
sns.countplot(y=df.iloc[:,1])
plt.show()

# %%
df['race/ethnicity'].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(y=df.iloc[:,2])
plt.show()

# %%
df['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.countplot(x='math score',data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8, 8), dpi=200)
sns.scatterplot(data=df, x='parental level of education', y='math score', hue='test preparation course', palette='Set1')
# Out:
# <Axes: xlabel='parental level of education', ylabel='math score'>

# %%
sns.pairplot(df)
